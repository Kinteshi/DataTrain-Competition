# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
sns.set()
sns.set_theme(style='ticks', color_codes=True)

# %%
# Load Train Data
data = pd.read_csv('data/treino.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11389 entries, 0 to 11388
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              11389 non-null  int64
#  1   idademae        11389 non-null  float64
#  2   estadocivilmae  11293 non-null  object
#  3   catprenatal     11349 non-null  object
#  4   qtdsemanas      11163 non-null  float64
#  5   tipoparto       11384 non-null  object
#  6   peso            11387 non-null  float64
#  7   malformacao     11085 non-null  object
#  8   sexo            11350 non-null  object
#  9   apgar1          11289 non-null  float64
#  10  apgar5          11294 non-null  float64
#  11  obito           11389 non-null  int64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 1.0+ MB

# %%
data.describe()
# Out:
#                  id      idademae    qtdsemanas          peso        apgar1  \
# count  11389.000000  11389.000000  11163.000000  11387.000000  11289.000000
# mean    8139.875230     25.793748     36.952611   2818.527883      7.503765
# std     4693.036873      6.468443      4.421121    930.575296      2.348192
# min        0.000000     11.000000     19.000000    150.000000      0.000000
# 25%     4078.000000     21.000000     37.000000   2550.000000      7.000000
# 50%     8085.000000     25.000000     38.000000   3060.000000      8.000000
# 75%    12198.000000     30.000000     39.000000   3412.000000      9.000000
# max    16269.000000     52.000000     45.000000   6651.000000     10.000000
#
#              apgar5         obito
# count  11294.000000  11389.000000
# mean       8.716664      0.260427
# std        2.120168      0.438887
# min        0.000000      0.000000
# 25%        9.000000      0.000000
# 50%        9.000000      0.000000
# 75%       10.000000      1.000000
# max       10.000000      1.000000

# %%
sns.histplot(data=data, x='idademae', hue='obito', kde=True);

# %%
data.estadocivilmae[data.estadocivilmae.isnull()] = 'nao informado'
sns.histplot(data=data, x='estadocivilmae', hue='obito');
# Out:
# <ipython-input-7-d52ba67e5d0c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.estadocivilmae[data.estadocivilmae.isnull()] = 'nao informado'

# %%
data.catprenatal[data.catprenatal.isnull()] = 'nao informado'
sns.histplot(data=data, x='catprenatal', hue='obito');
# Out:
# <ipython-input-8-c54154867816>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.catprenatal[data.catprenatal.isnull()] = 'nao informado'

# %%
sns.histplot(data=data, x='qtdsemanas', kde=True, binwidth=2);

# %%
data.tipoparto[data.tipoparto.isnull()] = 'desconhecido'
sns.histplot(data=data, x='tipoparto', hue='obito');
# Out:
# <ipython-input-10-ce85b1c05631>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.tipoparto[data.tipoparto.isnull()] = 'desconhecido'

# %%
sns.histplot(data=data, x='peso', hue='obito', kde=True);

# %%
data.malformacao[data.malformacao.isnull()] = 'desconhecido'
sns.histplot(data=data, x='malformacao', hue='obito');
# Out:
# <ipython-input-12-11764e3160d7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.malformacao[data.malformacao.isnull()] = 'desconhecido'

# %%
data.sexo[data.sexo.isnull()] = 'desconhecido'
sns.histplot(data=data, x='sexo', hue='obito');
# Out:
# <ipython-input-13-5f9d4555f0a5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.sexo[data.sexo.isnull()] = 'desconhecido'

# %%
sns.histplot(data=data, x='apgar1', hue='obito', kde=True);

# %%
sns.histplot(data=data, x='apgar5', hue='obito', kde=True);

# %%
data.corr()
# Out:
#                   id  idademae  qtdsemanas      peso    apgar1    apgar5  \
# id          1.000000 -0.001040    0.000790 -0.003471  0.008595  0.014887
# idademae   -0.001040  1.000000    0.029301  0.054437  0.045466  0.040019
# qtdsemanas  0.000790  0.029301    1.000000  0.819643  0.591498  0.585729
# peso       -0.003471  0.054437    0.819643  1.000000  0.593660  0.573869
# apgar1      0.008595  0.045466    0.591498  0.593660  1.000000  0.881047
# apgar5      0.014887  0.040019    0.585729  0.573869  0.881047  1.000000
# obito      -0.001090 -0.027939   -0.626797 -0.663052 -0.687433 -0.655362
#
#                obito
# id         -0.001090
# idademae   -0.027939
# qtdsemanas -0.626797
# peso       -0.663052
# apgar1     -0.687433
# apgar5     -0.655362
# obito       1.000000

# %%
sns.heatmap(data[['idademae', 'qtdsemanas', 'peso']].corr(), cmap='coolwarm');

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11389 entries, 0 to 11388
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              11389 non-null  int64
#  1   idademae        11389 non-null  float64
#  2   estadocivilmae  11389 non-null  object
#  3   catprenatal     11389 non-null  object
#  4   qtdsemanas      11163 non-null  float64
#  5   tipoparto       11389 non-null  object
#  6   peso            11387 non-null  float64
#  7   malformacao     11389 non-null  object
#  8   sexo            11389 non-null  object
#  9   apgar1          11289 non-null  float64
#  10  apgar5          11294 non-null  float64
#  11  obito           11389 non-null  int64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 1.0+ MB

# %%
sns.catplot(x="", y="qtdsemanas", kind="box", data=data, hue='obito')

# %%
for xcol in data.columns:
    sns.catplot(data=data, x=xcol, y='idademae', hue='obito');
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-0dbf723ede9a> in <module>
#       1 for xcol in data.columns:
# ----> 2     sns.catplot(data=data, x=xcol, y='idademae', hue='obito');
#
# c:\users\jefma\.virtualenvs\pibic-cht-mxsffsqm\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# c:\users\jefma\.virtualenvs\pibic-cht-mxsffsqm\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3832
#    3833     # Draw the plot onto the facets
# -> 3834     g.map_dataframe(plot_func, x=x, y=y, hue=hue, **plot_kws)
#    3835
#    3836     if p.orient == "h":
#
# c:\users\jefma\.virtualenvs\pibic-cht-mxsffsqm\lib\site-packages\seaborn\axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     748
#     749             # Draw the plot
# --> 750             self._facet_plot(func, ax, args, kwargs)
#     751
#     752         # Finalize the annotations and layout
#
# c:\users\jefma\.virtualenvs\pibic-cht-mxsffsqm\lib\site-packages\seaborn\axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     772                 plot_kwargs[key] = val
#     773             plot_args = []
# --> 774         func(*plot_args, **plot_kwargs)
#     775
#     776         # Sort out the supporting information
#
# c:\users\jefma\.virtualenvs\pibic-cht-mxsffsqm\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# c:\users\jefma\.virtualenvs\pibic-cht-mxsffsqm\lib\site-packages\seaborn\categorical.py in stripplot(x, y, hue, data, order, hue_order, jitter, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2807                        linewidth=linewidth))
#    2808
# -> 2809     plotter.plot(ax, kwargs)
#    2810     return ax
#    2811
#
# c:\users\jefma\.virtualenvs\pibic-cht-mxsffsqm\lib\site-packages\seaborn\categorical.py in plot(self, ax, kws)
#    1158     def plot(self, ax, kws):
#    1159         """Make the plot."""
# -> 1160         self.draw_stripplot(ax, kws)
#    1161         self.add_legend_data(ax)
#    1162         self.annotate_axes(ax)
#
# c:\users\jefma\.virtualenvs\pibic-cht-mxsffsqm\lib\site-packages\seaborn\categorical.py in draw_stripplot(self, ax, kws)
#    1127
#    1128                 strip_data = group_data[hue_mask]
# -> 1129                 point_colors = np.asarray(self.point_colors[i][hue_mask])
#    1130
#    1131                 # Plot the points in centered positions
#
# c:\users\jefma\.virtualenvs\pibic-cht-mxsffsqm\lib\site-packages\seaborn\categorical.py in point_colors(self)
#    1076                     # hue_color = self.colors[j]
#    1077                     if group_data.size:
# -> 1078                         group_colors[self.plot_hues[i] == level] = j
#    1079
#    1080             point_colors.append(group_colors)
#
# c:\users\jefma\.virtualenvs\pibic-cht-mxsffsqm\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# c:\users\jefma\.virtualenvs\pibic-cht-mxsffsqm\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     370         res_values = comparison_op(lvalues, rvalues, op)
#     371
# --> 372         return self._construct_result(res_values, name=res_name)
#     373
#     374     wrapper.__name__ = op_name
#
# c:\users\jefma\.virtualenvs\pibic-cht-mxsffsqm\lib\site-packages\pandas\core\series.py in _construct_result(self, result, name)
#    2767         # We do not pass dtype to ensure that the Series constructor
#    2768         #  does inference in the case where `result` has object-dtype.
# -> 2769         out = self._constructor(result, index=self.index)
#    2770         out = out.__finalize__(self)
#    2771
#
# c:\users\jefma\.virtualenvs\pibic-cht-mxsffsqm\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     327                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     328
# --> 329                 data = SingleBlockManager.from_array(data, index)
#     330
#     331         generic.NDFrame.__init__(self, data)
#
# c:\users\jefma\.virtualenvs\pibic-cht-mxsffsqm\lib\site-packages\pandas\core\internals\managers.py in from_array(cls, array, index)
#    1568         """
#    1569         block = make_block(array, placement=slice(0, len(index)), ndim=1)
# -> 1570         return cls(block, index)
#    1571
#    1572     def _post_setstate(self):
#
# c:\users\jefma\.virtualenvs\pibic-cht-mxsffsqm\lib\site-packages\pandas\core\internals\managers.py in __init__(self, block, axis, do_integrity_check, fastpath)
#    1537         fastpath=lib.no_default,
#    1538     ):
# -> 1539         assert isinstance(block, Block), type(block)
#    1540         assert isinstance(axis, Index), type(axis)
#    1541
#
# KeyboardInterrupt:
